# %% [markdown]
# ### Regular Expression

# %%
# from wscube tech

# %%
# ● A Regular Expressions is a special sequence of character that
                            # --------------------------------
# uses a search pattern to find a string or set of strings.

# ● It can detect the presence or absence of a text by matching it with 
# a particular pattern, and also can split a pattern into one or more sub patterns.

# %%
# explanation
#<----------------->

# Regular Expressions is a special sequence of character.
# means regex ka jo table hai jisme special characters hai.
# that is called regex. which is used to search something.


# ex:
# 1) "my email id is ayushi@gmail.com""
# I want to extract/fetch ayushi@gmail.com only from the above string

# 2) also can split a pattern into one or more sub patterns. it means
# for ex: ayushi@gmail.com this is our pattern
# and is pattern se hme only @gmail.com chahiye ya sirf user name ayushi chahiye.
#     to hm wo bhi extract kr skte hai. to is treh se bhi hm regex ko use kr skte hai.

#                      ayushi@gmail.com
#                            /\
#                      ayushi  @gmail.com

# %% [markdown]
# # Re Module:

# %%
# Python provides a re modue whose primary function is to offer a 
# search, where it takes a regular expression and a string.

# Import re is used to import the re module.


# \\re module is used to use regex

# %%
# explanation
#<-------------->

# 1) It takes a {regular expression} and a {string}.
                              # \             /
# it means                     {pattern},{string/string_variable (jo string search krna hai)/text}

# 2) we can do many things by string method also then why use are.
# see uses of regex below.

# %% [markdown]
# # Uses of RegEx:

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(24,24)); plt.imshow(plt.imread(r"C:\Users\Acer\OneDrive\Pictures\Screenshots\nlp\RegEx\Screenshot 2024-10-05 150103.png")); plt.axis('off'); plt.show()
# image at 3:27

# %%
# //Uses of Regular Expressions (Regex)
#<------------------------------------------->

# 1. Finding a Matching Pattern in a String
# When we want to fetch something from a string, we typically use indexing.
# However, indexing becomes impractical when dealing with very large strings, making it difficult to use string methods.
# Regex provides a solution to find a matching pattern in strings, regardless of whether they are small or large.

# 2. Phone Number Verification
# Example:
# +91-123456789  ✅
# +91-1234aac3   ❌
# We apply a pattern to a string to verify a phone number.
# If a phone number matches the defined pattern, it is considered correct.

# 3. Email Verification
# Example:
# ✅ ayushi@gmail.com
# ❌ AyushiJain@gmail.com
# We can use a regex pattern to verify the email format.
# In the example above, the correct email contains only lowercase characters.

# 4. Web Scraping
# Scraping means extracting important information from a website URL.
# For instance, if we have a website URL and want to find specific data, like phone numbers or email addresses, we can use regex to match and extract these patterns.


# Note
# We will explore this in more detail through videos later on.

# %% [markdown]
# # MetaCharacters in RegEx

# %%
# +---------+--------------------------------------------------------------+
# | Symbol  | Description                                                  |
# +---------+--------------------------------------------------------------+
# |    \    | Used to drop the special meaning of the character following it|
# |   []    | Represents a character class                                 |
# |    ^    | Matches the beginning                                        |
# |    $    | Matches the end                                              |
# |    .    | Matches any character except newline                         |
# |    |    | Means OR (Matches with any of the characters separated by it)|
# |    ?    | Matches zero or one occurrence                               |
# |    *    | Any number of occurrences (including 0 occurrences)         |
# |    +    | One or more occurrences                                      |
# |   {}    | Indicates the number of occurrences of a preceding regex to match|
# |   ()    | Encloses a group of regex                                   |
# +---------+--------------------------------------------------------------+

# %% [markdown]
# # //Code of Metacharacters

# %% [markdown]
# # search() vs findall() function

# %%
########## search() and findall() function
#<------------------------------------>
# search(): Finds the first occurrence of a regex pattern in a string and returns a match object or None(no output).
# findall(): Returns a list of all non-overlapping matches of a regex pattern in a string.

# //word meaning -> find and obtain means same

# In short
#<--------->
# search() -> it gives the index of only 1st matching values.
# findall() -> it does not gives the index. gives all the matching values only.

# %%
# re is used to use regex.
# re has 2 parameters (pattern,string)

# %%
# code 1.1)

# ques: search dot "." and get its index.

import re
b = "ayushi.jain@gmail.com"
match = re.search(r".",b) 
print(match)

# Notes: 
# 1. Jb bhi hm regex use krte hai to uske age r likhte hai. see in code.

# 2. Here dot is treated as special sequence/characters not pattern.
# so, we use backward slash to drop the special characters see below code. 👇
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
# code 1.2) \ backward slash

import re
b = "ayushi.jain@gmail.com"
match = re.search(r"\.",b)
print(match)

# Use Case of "\": We use the backslash when our pattern includes a special character.
                # It is Used to drop the special meaning of the character following it
# Out:
# <re.Match object; span=(6, 7), match='.'>

# %%
# code 2.1) [] sq brackets
#<------------------------>

# ques: search @ symbol

b = "ayushi.jain@gmail.com"
match = re.search(r"[@]",b)
match

# span=(11, 12) 12 is excluded
# Out:
# <re.Match object; span=(11, 12), match='@'>

# %%
# code 2.2) search l
#<--------------------->

c = "hello"
match = re.search(r"[l]",c)
match
# Out:
# <re.Match object; span=(2, 3), match='l'>

# %%
# code 2.3) using findall
#<--------------------------->

c = "hello"
match = re.findall(r"[l]",c)
match

# l occurs 2 times
# Out:
# ['l', 'l']

# %%
# code 2.4) 
b = "ayushi.jain@gmail.com"
match = re.findall(r"[a]",b)
match
# a occurs 3 times kha kha pe kr rha hai occur wo nhi ayega.
# findall does not gives the index/span of the matching elements/string.
# Out:
# ['a', 'a', 'a']

# %%
# code 3.1) ^ caret /circumflex symbol
#<------------------------------------->

# match the word starts with a

b = "ayushi.jain@gmail.com"
match = re.search(r"^a",b)
match
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
# code 3.2) 

match = re.search(r"^c",b)
match

# output not showing it means character c is not present at stating of b variable string.

# %%
# code 3.3)

match = re.search(r"^ayu",b)
match
# Out:
# <re.Match object; span=(0, 3), match='ayu'>

# %%
# code 4.1) $ dollar symbol
#<------------------------->

# match the end

b = "ayushi.jain@gmail.com"
match = re.search(r"com$",b)
match
# Out:
# <re.Match object; span=(18, 21), match='com'>

# %%
# code 4.2)
match = "ayushi.jain@gmail.com"
match = re.search(r"lo$",b)
match

# No output means No match means pattern not present in the b variable string.

# %%
# code 5.1) "." dot
#<------------------->

a = "charlie chaplin coa and the chocolate factory"

match = re.search(r"c.a",a)
match

# it only give first occurence
# Out:
# <re.Match object; span=(0, 3), match='cha'>

# %%
# code 5.2) # for dot we will use findall

# dot means bich me kuch bhi ho.
# hme wo sare matching word chahiye jha
# c ho, between me kuch bhi ek character, and then a ho

match = re.findall(r"c.a",a)
match

# 3 matches/output
# Out:
# ['cha', 'cha', 'coa']

# %%
# code 6.1) | or/pipe symbol
#<---------------------------->

# or operator/meta character is same as or operator.
# if atleast one is true then print.


a = "charlie chaplin coa and the chocolate factory"

match = re.findall(r"cha|fac",a)
match
# Out:
# ['cha', 'cha', 'fac']

# %%
# code 6.2)
match = re.findall(r"cha|foc",a)
match
# Out:
# ['cha', 'cha']

# %%
# code 6.3)
match = re.findall(r"cha|tor",a)
match
# Out:
# ['cha', 'cha', 'tor']

# %%
# code 6.4)

match = re.search(r"rli|tor",a)
match

# rli match index -> (3, 6)
# tor not in output becoz search only gives the 1st occurence.
# Out:
# <re.Match object; span=(3, 6), match='rli'>

# %%
# code 6.5

match = re.search(r"ali|tor",a)
match

# ali not in string
# span=(41, 44), match='tor'>
# Out:
# <re.Match object; span=(41, 44), match='tor'>

# %%
# code 7) ? question mark
#<---------------------------->

a = "charlie chchaplin coa and the chocolate factor"

match = re.findall(r"ch?a",a)
match
# Out:
# ['cha', 'cha']

# %%
# code 8.1) * star/asterik sign
#<------------------------------>

a = "charlie chchaplin coa and the chocolate factor"
match = re.findall(r"ch*a",a)
match
# Out:
# ['cha', 'cha']

# %%
# code 8.2) 

a = "charlie chachaplin coa and the chocolate factor"

match = re.findall(r"ch*a",a)
match
# Out:
# ['cha', 'cha', 'cha']

# %%
# code 9.1) + metacharacter
#<------------------------->

# One or more occurrences

d = "xyz,yz,xyzz,xyyz,xxzzy,zyz,xxyyzz,xyzxyz"

match = re.findall(r"xy+z",d)
match
# Out:
# ['xyz', 'xyz', 'xyyz', 'xyyz', 'xyz', 'xyz']

# %%
# code 9.2)
match = re.findall(r"xy*z",d)
match
# Out:
# ['xyz', 'xyz', 'xyyz', 'xz', 'xyyz', 'xyz', 'xyz']

# %% [markdown]
# # mycode) Understanding ? , *, +

# %%
# ?: Matches zero or one occurrence  
#<---------------------------------------->

import re
a = "ca cha chha coa"
match = re.findall(r"ch?a",a)
match

# ca      -> ca  (0 h ok)
# cha -> cha -> (1 h ok)

# chha    -> no output (2 h not ok)
# coa     -> no output (any character other than h is not ok)
# Out:
# ['ca', 'cha']

# %%
# *: Any number of occurrences (including 0 occurrences)
#<---------------------------------------------------------->

# //* matches zero or any occurance
import re
a = "ca cha chha coa"
match = re.findall(r"ch*a",a)
match

# ca      -> ca  (0 h ok)
# cha -> cha -> (1 h ok)
# chha    -> no output (2 h also ok)

# coa     -> no output (any character other than h is not ok)
# Out:
# ['ca', 'cha', 'chha']

# %%
# +: One or more occurrences

import re
a = "ca cha chha coa"
match = re.findall(r"ch+a",a)
match

# ca      -> ca  (charcter before + sign has zero occurance so not match)

# cha -> cha -> (1 occurance ok match)
# chha    -> no output (2 occurance also ok)

# coa     -> no output (any character other than h is not ok)
# Out:
# ['cha', 'chha']

# %%
# comparision (?, *, +)
#<------------------------->

# string = cha
# ? -> ch?a (if zero or one occurance of character before sign?  then match/print)
# * -> ch*a (if zero or any occurance of character before sign? print)
# + -> ch+a (if one or any occurance of character before sign+ then it will print)

# here, character before sign is h.

# so note that + plus me agr plus sign se pehle wala character string hona compulsory hai
# wrna wo wala string print nhi hoga. becoz isme sign se pehle wale
# character ka ek occurance hona compulsory hai.

# %%
# code 10.1: {} curly bracket/braces
#<------------------------------------>

# It Indicates the number of occurrences of a preceding regex to match

d = "xyz,yz,xyzz,xyyz,xxzzy,zyz,xxyyzz,xyzxyz"

match = re.findall(r"x{2,4}",d)
match
# Out:
# ['xx', 'xx']

# %%
# code 10.2) xyyyz
d = "xyz,yz,xyzz,xyyyz,xxzzy,zyz,xxyyzz,xyzxyz"

match = re.findall(r"y{2,4}",d)
match
# Out:
# ['yyy', 'yy']

# %%
# code 10.3) xyyyyz
d = "xyz,yz,xyzz,xyyyyz,xxzzy,zyz,xxyyzz,xyzxyz"

match = re.findall(r"y{2,4}",d)
match
# Out:
# ['yyyy', 'yy']

# %%
# code 10.4) xyyyyyz
d = "xyz,yz,xyzz,xyyyyyz,xxzzy,zyz,xxyyzz,xyzxyz"

match = re.findall(r"y{2,4}",d)
match
# Out:
# ['yyyy', 'yy']

# %%
# code 10.5) xyyyyyyz
d = "xyz,yz,xyzz,xyyyyyyz,xxzzy,zyz,xxyyzz,xyzxyz"

match = re.findall(r"y{2,4}",d)
match

# output structure
# xyyyyyyz -> 1) yyyy and 2) yy
# xxyyzz -> 3) yy
# Out:
# ['yyyy', 'yy', 'yy']

# %%
# code 11) () paranthesis
#<--------------------------->

d = "xyz,yz,xyzz,xyyyz,xxzzy,zyz,xxyyzz,xyzxyz"
match = re.findall(r"(x|z)yz",d)
print(match)


# (x|z)yz -> it means starting me x and z hona chahiye. and then yz.
# Out:
# ['x', 'x', 'z', 'x', 'x']

# %% [markdown]
# # Special Sequences in RegEx

# %%
# ● Special sequences do not match for the actual 
# character in the string instead it tells the specific 
# location in the search string where the match must 
# occur.

# ● It makes it easier to write commonly used patterns.

# %%
# Special                 Description
# Sequence
# ----------------------------------------------------------------------------
# \A              Matches if the string begins with the gives character

# \b              Matches if the word begins or ends with the
#                 given character. \b(string) will check for the 
#                 beginning of the word and (string)\b will 
#                 check for the ending of the word.

# \B              It is the opposite of the \b i.e. the string 
#                 should not start or end with the given regex. 

# \d               Matches any decimal digit, this is equivalent 
#                  to the set class [0-9]

# \D               Matches any non-digit character, this is 
#                  equivalent to the set class [^0-9] 

# \s               Matches any whitespace character. 

# \S               Matches any non-whitespace character 

# \w               Matches any alphanumeric character, this is 
#                  equivalent to the class [a-zA-Z0-9_]

# \W               Matches any non-alphanumeric character.

# \Z               Matches if the string ends with the given regex


# \d ki defination me decimal ka mtlb decial point nhi hai.
# it means decimal digit/place number means 0 to 9
# in simple word \d gives the numbers.

# %% [markdown]
# # //code of special sequences

# %%
# code 1.1) \A: match begins
#<----------------------------->

# find word starts with har
#<------------------------->

import re

a = "harry potter"
match = re.search(r'\Ahar',a)
print(match)

# \Ahar -> it means starting me agr har hai kisi string me, then it will obtail.
            # and gives their index.

# Note: "harry potter" is a one string.
          # its starting character starts from h not p.
# Out:
# <re.Match object; span=(0, 3), match='har'>

# %%
# code 1.2) find index of the word starts with pot
#<-------------------------------------------------->
a = "harry potter"
match = re.search(r'\Apot',a)
print(match)
# Out:
# None

# %%
# code 1.3) find index of the word starts with h
#<------------------------------------------------>
a = "harry potter"
match = re.search(r'\Ah',a)
print(match)
# Out:
# <re.Match object; span=(0, 1), match='h'>

# %%
# code 2.1) \b(string) begining, (string)\b ending
#<----------------------------------------------------->

# is h at end

a = "harry potter"
match = re.search(r'h\b',a)
print(match)
# Out:
# None

# %%
# code 2.2) check that is h at starting?
a = "harry potter"
match = re.search(r'\bh',a)
print(match)
# Out:
# <re.Match object; span=(0, 1), match='h'>

# %%
# code 3.1) \B opposite of \b
#<-------------==-------------->

a = "harry potter"
match = re.search(r'ha\B',a)
print(match)

# 'ha\B -> means ha start me check kr rha hai
# and small b "\b" me esa string pehle hai to wo end me check krta hai.
# Out:
# <re.Match object; span=(0, 2), match='ha'>

# %%
# code 3.2)
a = "harry potter"
match = re.search(r'\Ber',a)
print(match)

# '\Ber' -> jiske last me er hai uska index
# Out:
# <re.Match object; span=(10, 12), match='er'>

# %%
# code 4.1) \d -> it obtain all the numbers
a = "harry1 potter2"
match = re.findall(r'\d',a)
print(match)
# Out:
# ['1', '2']

# %%
# code 5) \D   
# opposite of small backslash d
# It obtain everthing also spacy,symbols except numbers.
a = "harry1 potter234@5"
match = re.findall(r'\D',a)
print(match)

# space is also considered an element so it also obtain here.
# Out:
# ['h', 'a', 'r', 'r', 'y', ' ', 'p', 'o', 't', 't', 'e', 'r', '@']

# %%
# //regex related terms -> extract, match, fetch obtain.

# %%
# code 6) \s -> obtain whitespaces
#<------------------------------------->

a = "harry1 potter23 4@5"
match = re.findall(r'\s',a)
print(match)
# Out:
# [' ', ' ']

# %%
# code 7.1) \S (capital S)
#<----------------------->

# obtain everything except whitespaces

a = "harry1 potter23 4@5"
match = re.findall(r'\S',a)
print(match)
# Out:
# ['h', 'a', 'r', 'r', 'y', '1', 'p', 'o', 't', 't', 'e', 'r', '2', '3', '4', '@', '5']

# %%
# code 7.2) mycode:

# print nhi likha to vertically show hua.
a = "harry1 potter23 4@5"
match = re.findall(r'\S',a)
match
# Out:
# ['h',
#  'a',
#  'r',
#  'r',
#  'y',
#  '1',
#  'p',
#  'o',
#  't',
#  't',
#  'e',
#  'r',
#  '2',
#  '3',
#  '4',
#  '@',
#  '5']

# %%
# Note: agr hme abhi smj ni aa rha ki kya ho rha hai.
# then no problem. abhi abhi age smj aa jayega.
# how to use regex in phone no. verification, email verification & web scrapping etc.

# %%
# code 8) \w: (small w)
#<--------------------->

# matches alphabet and numeric (alphanumeric) also underscore

a = "harry1 potter23 4@5"
match = re.findall(r'\w',a)
print(match)
# Out:
# ['h', 'a', 'r', 'r', 'y', '1', 'p', 'o', 't', 't', 'e', 'r', '2', '3', '4', '5']

# %%
# code 9.1) \W: (capital W)
#<----------------------->

# non alphanumeric
# everything except alphabet and numbers
# not obtain underscore bcoz it counts as alphanumeric character.

a = "harry1 potter23 4@5"
match = re.findall(r'\W',a)
print(match)

# Here non alphanumeric character is space and @
# Out:
# [' ', ' ', '@']

# %%
# code 9.1) mycode
#<-------------------->

import re
text = "apple mango banana"
words = re.split(r'\W+',text)
print(words)

# in this code I split the words by space.
# Out:
# ['apple', 'mango', 'banana']

# %%
# code 10.1) \Z: matches the end index
#<--------------------------------------->

# same as (string)\B

a = "harry1 potter23 4@5"
match = re.search(r'5\Z',a)
print(match)
# Out:
# <re.Match object; span=(18, 19), match='5'>

# %%
# code 10.2)
a = "harry1 potter23 4@5"
match = re.search(r'h\Z',a)
print(match)
# Out:
# None

# %%
# code 10.3)
a = "harry1 potter23 4@5"
match = re.search(r'@5\Z',a)
print(match)
# Out:
# <re.Match object; span=(17, 19), match='@5'>

# %% [markdown]
# # RegEx Sets

# %%
# A set is a set of characters inside a pair of square 
# brackets [] with a special meaning.

# %%
# set           Description
# ---------------------------------------------------------------------------

# [atx] Returns a match where one of the specified characters (a, t, or x) are present.
# [a-h] Returns a match for any lower case character, alphabetically between a and h.
# [^atx] Returns a match for any character EXCEPT a, t, and x.
# [0123] Returns a match where any of the specified digits (0,1,2 or 3) are present.
# [0-9]  Returns a match for any digit between 0 and 9.
# [0-7][0-9] Returns a match for any two-digit numbers form 00 and 79.
# [a-zA-Z] Returns a match for any character alphabetically between a and z, lower case and upper case.
# [+]      In sets, +, *, ., |, (), $, {} has no special meaning, so [+] means: returns a match for any + character in the string.


# [^atx] -> means caret atx

# %% [markdown]
# # codes RegEx Sets

# %%
# code 1) [atx]
#<------------------>

import re
a = 'charlie and the chocolate factory'
match = re.findall("[atx]",a)
print(match)

# var a ke string me jha jha atx hai wo aa jayega output me.
# Out:
# ['a', 'a', 't', 'a', 't', 'a', 't']

# %%
# mycode
#<----------->

match = re.findall("[at]",a)
print(match)

# it will give a and t
# Out:
# ['a', 'a', 't', 'a', 't', 'a', 't']

# %%
# code 2) [^atx]
#<------------------------->

match = re.findall("[^atx]",a)
print(match)

# all characters except atx
# special characters, no.s will also obtain
# Out:
# ['c', 'h', 'r', 'l', 'i', 'e', ' ', 'n', 'd', ' ', 'h', 'e', ' ', 'c', 'h', 'o', 'c', 'o', 'l', 'e', ' ', 'f', 'c', 'o', 'r', 'y']

# %%
# code 3) [a-t] : a to t


match = re.findall("[a-t]",a)
print(match)
# Out:
# ['c', 'h', 'a', 'r', 'l', 'i', 'e', 'a', 'n', 'd', 't', 'h', 'e', 'c', 'h', 'o', 'c', 'o', 'l', 'a', 't', 'e', 'f', 'a', 'c', 't', 'o', 'r']

# %%
# code 4.1) [0123]

match = re.findall("[1234]",a)
print(match)

# no numbers in the string
# Out:
# []

# %%
# code 4.2) 

b = "123john#$@^6773"
match = re.findall("[123456]",b)
print(match)
# Out:
# ['1', '2', '3', '6', '3']

# %%
# code 5) [0-9]: for obtain all numbers
#<--------------------------------------->

match = re.findall("[0-9]",b)
print(match)
# Out:
# ['1', '2', '3', '6', '7', '7', '3']

# %%
# code 6.1) [0-7][0-9]
#<------------------------>

# it means obtain numbers which has starting value 0to9 and ending value 0to9


b = "12hi03john#$@^67HELLO73,89"

match = re.findall("[0-7][0-9]",b)
print(match)
# Out:
# ['12', '03', '67', '73']

# %%
# code 6.2) understanding code
b = "123hello4"

match = re.findall("[0-7][0-9]",b)
print(match)
# Out:
# ['12']

# %%
# code 6.3) uc
b = "1234hello5"

match = re.findall("[0-7][0-9]",b)
print(match)
# Out:
# ['12', '34']

# %%
# code 6.4) uc
b = "9123hello4"

match = re.findall("[0-7][0-9]",b)
print(match)
# Out:
# ['12']

# %%
# code 6.5) uc
b = "9123hello4"

match = re.findall("[0-9][0-7]",b)
print(match)
# Out:
# ['91', '23']

# %%
# code 7.1) [a-zA-Z] 
#<------------------------------------------------------------->

# It is used to obtain All letters/alphabets lower and upper both
b = "12hi03john#$@^67HELLO73,89"

match = re.findall("[a-zA-Z]",b)
print(match)



# [a-zA-Z] or [a-zA-Z] order not matter see below code same output as it.
# note: [a-zA-Z] -> ye single sq bracket me hi hai
# Out:
# ['h', 'i', 'j', 'o', 'h', 'n', 'H', 'E', 'L', 'L', 'O']

# %%
# code 7.2) understanding code
b = "12hi03john#$@^67HELLO73,89"
match = re.findall("[A-Za-z]",b)
print(match)
# Out:
# ['h', 'i', 'j', 'o', 'h', 'n', 'H', 'E', 'L', 'L', 'O']

# %%
# code 8) [+] and more symbols
#<-------------------------------->

# Note: imp: agr hm sq brackets ke andr koi sa bhi special character insert krenge.
# to code ise special sequence/characters treat ya metacharacters treat nhi hoga.
# code in symbols ko normal characters ke hi treh treat krega.



b = "12hi03john#$@^67HELLO73,89"
match = re.findall("[$]",b)
print(match)
# Out:
# ['$']

# %%
# Note: 
# agr abhi tk hme cheeze strik ni kr rhe. means smj ni aa rha
# ki hm ye use ku kr rhe hai. then no problem.
# jb hm ise video me phone no. verify krenge, email verify krenga and at the same time
# ek url leke data ko scrap krenge. uske badh hme cheeze clear ho jayegi.
# that why regular express is used.


# age ane wale sessions me hm jo hmne meta characters, special sequence and 
# sets in regex in tino ko merge krke hm patterns nikalenge strings ke andr se
#     like obtain name, numbers etc.

# %% [markdown]
# # //finditer

# %%
# finditer gives all the matching value index.
#<---------------------------------------->

# by code with harry

a = "123456"
matches = re.finditer(r'[0-9]',a)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 1), match='1'>
# <re.Match object; span=(1, 2), match='2'>
# <re.Match object; span=(2, 3), match='3'>
# <re.Match object; span=(3, 4), match='4'>
# <re.Match object; span=(4, 5), match='5'>
# <re.Match object; span=(5, 6), match='6'>

# %% [markdown]
# # Functions in RegEx

# %%
# // 1st we will understand function
# // and we will also see practical implementation with example

# %%
# re.findall()
# --------------
# Return all non-overlapping matches of pattern in string, as a list of 
# strings. The string is scanned left-to-right, and matches are returned 
# in the order found.

# /hello
# ------>  left to right/


# re.compile()
# --------------
# Regular expressions are compiled into pattern objects, which have
# methods for various operations such as searching for pattern
# matches or performing string substitutions.


# re.split()
# --------------
# Split string by the occurrences of a character or a pattern, upon 
# finding that pattern, the remaining characters from the string are 
# returned as part of the resulting list.


# re.sub():
# --------------
# The method returns a string where matched occurences are 
# replaced with the content of replace variable.


# re.subn():
# --------------
# subn() is similar to sub() in all ways, except in its way of providing 
# output. It returns a tuple with a count of the total of replacement and 
# the new string rather than just the string. 


# re.escape():
# ---------------
# Returns string with all non-alphanumerics backslashed, this is useful 
# if you want to match an arbitrary literal string that may have regular
# expression metacharacters in it.


# re.search()
# ---------------
# This method either returns None (if the pattern doesn't match), or a  
#     re. This method stops after the first match, so this is best suited for 
# testing a regular expression more than extracting data.

# %%
# Explanation
#<--------------->

# 3. re.split() -> John has scored 98 marks.
#              ----------------    ------

# 98 hmara pattern rhe use pattern se bhi hm split kr skte hai.


# 4. re.sub(): -> String => John David -> John_David
# we can replace spacy by anything

# so here we have 3 parameters.
# pattern, replacement string, input string



# 5. re.subn 
------------

# ex: we have a string => John David Peter Lisa -> John_David_Peter_Lisa

# it is similar to sub but isme jitne replacement honge space ki jgah.
# wo count hoke hme ek tuple ke form me bhi milega.
# It means it also show the no. of replacement but not sub() function show it

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(24,24)); plt.imshow(plt.imread(r"C:\Users\Acer\OneDrive\Pictures\Screenshots\nlp\RegEx\Screenshot 2024-10-10 235156.png")); plt.axis('off'); plt.show()

# image at 45:53

# %% [markdown]
# # Practical Implementation of functions

# %%
# Note: now, we have covered everything here like 
# meta characters, special sequences and sets also.
# wo now we will make patterns by using its combination.

# %%
# code 1.1) re.findall
#<-------------------->
import re

a = """John has scored 89 marks
Lisa has scored 90 marks
David has scored 70 marks"""

print(re.findall("\d+",a))
# Out:
# ['89', '90', '70']

# %%
# code 1.2)

print(re.findall("\d",a))
# Out:
# ['8', '9', '9', '0', '7', '0']

# %% [markdown]
# ## //DIFFERENCE B\W \d and \d+

# %%
# DIFFERENCE B\W \d and \d+
#<------------------------------->
# \d give the no. individually.
# \d+ reoccuring values also obtained
#    means jo no. sath me hai wo sath me hi print hoga.


# In simple + plus ka use krne se wo matching character to ayega.
# but wo character jis word me hai wo pure word ke sath ayega.
# + means get complete particular word
# + plus means getting all values attached with matching charater

# %%
# code 1.3) extracting names
#<--------------------------->

print(re.findall(r'[A-Z][a-z]*',a))
# Out:
# ['John', 'Lisa', 'David']

# %%
print(re.findall(r'[A-Z][a-z]+',a))
# Out:
# ['John', 'Lisa', 'David']

# %%
print(re.findall(r'[A-Z][a-z]',a))
# Out:
# ['Jo', 'Li', 'Da']

# %%
print(re.findall(r'[a-z][A-Z]',a))
# Out:
# []

# %% [markdown]
# # Note: imp +,*

# %%
# plus+ or start* -> pattern ke age +,* lgane se matching values ke age reoccur krne wali values bhi aa jata hai.
# means inse pura word aa jata hai.

# %%
# code 2.1) re.compile() function
#<-------------------------------->

# obtaining alphabets a to d
p = re.compile("[a-d]")
print(re.findall(p,a))
# Out:
# ['a', 'c', 'd', 'a', 'a', 'a', 'c', 'd', 'a', 'a', 'd', 'a', 'c', 'd', 'a']

# %%
# code 2.2) obtaining alphabets 0-9
p = re.compile("[0-9]") # we can \d also see below
print(re.findall(p,a))
# Out:
# ['8', '9', '9', '0', '7', '0']

# %%
# code 2.3) obtaining alphabets 0-9
p = re.compile("[\d]")
print(re.findall(p,a))
# Out:
# ['8', '9', '9', '0', '7', '0']

# %%
# code 2.4) + -> means obtaining reoccuring values also
p = re.compile("[\d]+")
print(re.findall(p,a))
# Out:
# ['89', '90', '70']

# %%
# code 2.5) 
aa = "89 900 70"
p = re.compile("[\d]+")
print(re.findall(p,aa))

# Note: +reoccuring has no limit bound. wo pure word ko print kr dega +.
# Out:
# ['89', '900', '70']

# %% [markdown]
# ## //without re.compile() vs re.compile()

# %%
# Using re.compile() is more efficient and can lead to faster code execution, 
# especially when the same pattern is reused multiple times, like in a loop.
# see example below 👇:

# %%
# Ex:1 Without re.compile()
import re

aaa = "Alice scored 95, Bob scored 88, Carol scored 92"
for i in range(3):
    result = re.findall(r"\d+", aaa)  # Finds all numbers in the string
    print(result)
# Out:
# ['95', '88', '92']
# ['95', '88', '92']
# ['95', '88', '92']

# %%
# Ex:2 With re.compile()

import re

aaa = "Alice scored 95, Bob scored 88, Carol scored 92"
pattern = re.compile(r"\d+")
for i in range(3):
    result = pattern.findall(aaa)  # Using the compiled pattern
    print(result)
# Out:
# ['95', '88', '92']
# ['95', '88', '92']
# ['95', '88', '92']

# %%
# code 3.1) re.split()
#<------------------->

# splitting where the numbers
print(re.split("\d+",a))
# Out:
# ['John has scored ', ' marks\nLisa has scored ', ' marks\nDavid has scored ', ' marks']

# %%
# code 3.2)

b = "fantastic 5 turtles"
print(re.split("\d+",b))
# \d+ means numbers/digits
# here split at 5. 5 remove ho jayega.
# and numbers se split ho jayega..
# Out:
# ['fantastic ', ' turtles']

# %%
# code 4) re.sub(): substitute

# > re.sub() is a function that replaces occurrences of a pattern in a string with a specified replacement.
# > means sub word ke badh jo space ya next line, ya tab space hai un sbki passing element se replace kr deta hai.
# > Note: next line ke liye output me /n ese ana chahiye tha but wo bhi replace ho jata hai yha.


# In short:
# sub is used to replace spaces and also next line space.

import re
print(re.sub("\s","",a)) # output in without space format
print(re.sub("\s+","",b))
print(re.sub("\s+",",",b)) # output in comma

# re.sub(pattern, repl, string)  
# repl means replacement string
# Out:
# Johnhasscored89marksLisahasscored90marksDavidhasscored70marks
# fantastic5turtles
# fantastic,5,turtles

# %%
# code 5) re.subn : substitute and number
#<----------------------------------------->
print(re.subn("\s+","",a))

# >\s+ gives the value in tuple format.

# >14 means how many times replacement happen.
# means 14 jgah space hai wha replacement hua hai.
# space ko kisi bhi cheez se replace kr skte hai like comman, ya phir no space as this code.
# it is same as end=''


# so subn means
# Out:
# ('Johnhasscored89marksLisahasscored90marksDavidhasscored70marks', 14)

# %%
# code 6) re.escape()
#<---------------------->

print(re.escape(a))

# it takes only 1 parameter.
# it replace by backslash.
# Out:
# John\ has\ scored\ 89\ marks\
# Lisa\ has\ scored\ 90\ marks\
# David\ has\ scored\ 70\ marks

# %%
# code 7) re.search()
#<----------------------->

print(re.search("\d+",a))

# search gives the index and value of only 1st matching value
# we can use findall if we want all the values.
# and we can use finditer to get the index and values
# Out:
# <re.Match object; span=(16, 18), match='89'>

# %% [markdown]
# # Match Object in RegEx

# %%
# A Match object contains all the information about the 
# search and the result and if there is no match found then 
# None will be returned.

# //explanation:
#<---------------->
# match object like when we use search function.
# then search function ke sath hmare pass jitne bhi details aa jate hai.
# like string details, ya hm kon se regular expression use kr rhe hai uske details,
# starting index, ending index, span.

# //In short
#<---------->
# match ka ye kam hai ki ye search ke andr jitne bhi information hai.
# match object use apne pass rkhta hai.
# and then if we want to get different different information.
# then we can get these different different information by applying function.

# %%
# code 1)
import re

a = "John has scored 98 marks"

match = re.search("\d+",a) # \d+ means reoccuring values
print(match)

# //Now we will use its functions
print(match.re) # means which regular expression are use in this code.
print(match.string) # obtaining string (wo string jiske upar match kr rhe hai)
print(match.start()) # stating span
print(match.end())   # ending span
print(match.span())  # start, end value/index both
print(match.group()) # group means match value



# explanation
#<---------------->
# > \d is a regex pattern that matches any digit (0-9).
# > + is a quantifier that ensures the preceding pattern (\d) is matched one or more times. This means it will match sequences of digits, whether they are single or multi-digit numbers.
# > Therefore, the pattern \d+ will match the first occurrence of digits in the string a. In this case, it will match the number 98.

# In simple + plus ka use krne se wo matching character to ayega.
# but wo character jis word me hai wo pure word ke sath ayega.
# Out:
# <re.Match object; span=(16, 18), match='98'>
# re.compile('\\d+')
# John has scored 98 marks
# 16
# 18
# (16, 18)
# 98

# %%
# code 2)
a = "John has scored 98 marks"
match = re.search("\w{2} s",a)
print(match)


# \w{2} s -> 
 # means print alphanumeric value in range 2 which is occur at space s
# Out:
# <re.Match object; span=(6, 10), match='as s'>

# %%
# code 3)

n = "1a2345 34"
re.search("\w5",n)

# \w5 -> means alphanumeric and 5.
# 5 match ho gya to use pehle jo alphanumeric value hai use 5 ke sath print kro.
# Out:
# <re.Match object; span=(4, 6), match='45'>

# %%
# code 4)

re.search("\w{2}",n)
# \w{2} -> print 2 alphanumeric values.
#         {2} means range 2. (0th index, 1st index value)
# Out:
# <re.Match object; span=(0, 2), match='1a'>

# %%
re.search("\w{2} 3",n)

# \w{2} 3 -> means 2alphanumeric_value + space + 3
# Out:
# <re.Match object; span=(4, 8), match='45 3'>

# %%
n = "1a2345 34"
re.search("3\w{2}",n)

# 3\w{2} -> means 3+2alphanumeric_value

# it means 3 ko match kro. agr wo hai to uske age ke 2 alpha numeric value print kr do.
# Out:
# <re.Match object; span=(3, 6), match='345'>

# %%
n = "123456"
re.search("3\w{2} ",n)

# ("3\w{2} " -> means 3+2alphanumeric+space. agr esa khi pe hai to match ho jayega.
      # means match 3 and print 3 + it's next till 2 values.

# %% [markdown]
# # Phone Number and Email Verification and Web Scrapping Using Regex

# %% [markdown]
# ### 1) Phone number verification

# %%
# code 1.1)
import re

phn = "222-444-8787" # //this is valid phone no.

if re.search("\d{3}-\d{3}-\d{4}",phn):
    print ("it is a verified number")
else:
    print ("incorrect number")

# I f the phn no. satisfied the pattern condition then it is a verified number.
# Out:
# it is a verified number

# %%
# code 1.2)
import re

phn = "222-4a4-8787"

if re.search("\d{3}-\d{3}-\d{4}",phn):
    print ("it is a verified number")
else:
    print ("incorrect number")
# Out:
# incorrect number

# %%
# code 1.3)
import re

phn = "222-45464-8787"

if re.search("\d{3}-\d{3}-\d{4}",phn):
    print ("it is a verified number")
else:
    print ("incorrect number")
# Out:
# incorrect number

# %% [markdown]
# ### 2) email verification

# %%
# Email refers to an electronic mail address that follows a specific format:
#<------------------------------------------------------------------------------>

# username@domain


# > username: The part before the @ symbol. It identifies the user.
# > domain: The part after the @ symbol, like gmail.com, yahoo.com, or example.co.


# Common parts of an email:
# #<-------------------------->
# 1. Service Providers (Domains):
#    .gmail.com: For Gmail (Google).
#    .yahoo.com: For Yahoo Mail.
#    .outlook.com: For Outlook (Microsoft).
#    .example.co: This could be for companies, organizations, or other services.

                             
# 2. Top-Level Domains (TLDs):
# #<----------------------------->
#     .com: Commercial organizations.
#     .org: Non-profit organizations.
#     .net: Network-related services.
#     .co: Common for companies or Colombia (geographical TLD).

        
# Examples:
# . abc@gmail.com: A valid Gmail address.
# . xyz@yahoo.com: A valid Yahoo address.
# . john.doe@company.co: A valid corporate email.

        
# So, when you say email, you're talking about the entire structure (username@domain.com). Domains like gmail.com, yahoo.com, or .co are just parts of different email providers or organizations. All valid combinations following the email format are considered email addresses

# %%
email = "john78@gmail.com john@.com    david.989@yahoo.com"

print(re.findall("[\w._%]{0,20}@[\w-].[A-Za-z]{2,3}",email))

print(len(re.findall("[\w._%]{0,20}@[\w-].[A-Za-z]{2,3}",email))) # length(len) gives how many matches
# Out:
# ['john78@gmail', 'david.989@yahoo']
# 2

# %% [markdown]
# ### 3) Web Scrapping

# %%
# Importing 2 required module
#<----------------------------->

import urllib.request
from re import findall

url = "https://www.summet.com/dmsi/html/codesamples/addresses.html"

a = urllib.request.urlopen(url)
html = a.read()
htmlstr = html.decode()
phn = re.findall("\(\d{3}\) \d{3}-\d{4}",htmlstr)

for i in phn:
    print(i)
# Out:
# (257) 563-7401
# (372) 587-2335
# (786) 713-8616
# (793) 151-6230
# (492) 709-6392
# (654) 393-5734
# (404) 960-3807
# (314) 244-6306
# (947) 278-5929
# (684) 579-1879
# (389) 737-2852
# (660) 663-4518
# (608) 265-2215
# (959) 119-8364
# (468) 353-2641
# (248) 675-4007
# (939) 353-1107
# (570) 873-7090
# (302) 259-2375
# (717) 450-4729
# (453) 391-4650
# (559) 104-5475
# (387) 142-9434
# (516) 745-4496
# (326) 677-3419
# (746) 679-2470
# (455) 430-0989
# (490) 936-4694
# (985) 834-8285
# (662) 661-1446
# (802) 668-8240
# (477) 768-9247
# (791) 239-9057
# (832) 109-0213
# (837) 196-3274
# (268) 442-2428
# (850) 676-5117
# (861) 546-5032
# (176) 805-4108
# (715) 912-6931
# (993) 554-0563
# (357) 616-5411
# (121) 347-0086
# (304) 506-6314
# (425) 288-2332
# (145) 987-4962
# (187) 582-9707
# (750) 558-3965
# (492) 467-3131
# (774) 914-2510
# (888) 106-8550
# (539) 567-3573
# (693) 337-2849
# (545) 604-9386
# (221) 156-5026
# (414) 876-0865
# (932) 726-8645
# (726) 710-9826
# ...

# %%
# mycode gmail verfication
#<--------------------------->
import re
a = input("enter you mail: ")
try:
    pattern = re.search(r"[\w+.%-]+@gmail\.com", a)
    g = pattern.group()

    if a == g:
        print("Valid_email")
    else:
        print("No")
except:
    print("Invalid email")

# \w is also special sequence. we have already discussed the special sequence character in the above table.
# Note:backslash is used to escape the special sequence character. here dot is special sequence character. so I drop it. 

# Note: is code me try except lgana is compulsory. bcoz agr user wrong email dalega. to hmare pattern me kuch bhi extract ni hoga.
# jiske bje se pattern.group me function me error ayega. agr use koi value ni mili to. 
# so here i use try except.
# Out:
# enter you mail:  fmdfd
# Invalid email

# %% [markdown]
# # --------------------------------------------------------------------------------------------

# %%
# Another video of wscube tech :👇

# %% [markdown]
# # Email Validation in Python (Using RegEx)

# %% [markdown]
# # TO DO understanding

# %%
# conditions
#<-------------->
# a-z //(alphabet a to z, all small)
# 0-9 
# ._ time 1
# @ time 1
# . 2,3   // .com, .in, .co


# Notes
#<--------->
# a-z means first character should be alphabet and in lower case in email.

# Note1) dot and underscore -> @ at the rate se pehle only 1 time hi hona chahiye.
# more than 1 hua. to wo wrong email. hota hai.

# Note2) . 2,3  -> dot ki position piche se 2nd ya 3rd pe hona chahiye.
# // .com, .in, .co

# %%
import re
email_condition="^[a-z]+[\._]?[a-z 0-9]+[@]\w+[\.]\w{2,3}$"
user_email=input(' Enter your Email : ')

if re.search(email_condition,user_email):
    print("Right Email ")
else:
    print("Wrong Email ")


# explanation

# 1) ^ or startswith -> 1st character should be alphabet and in lower case in email.
# 2) ^[a-z] -> means startswith lower case alphabet
# 3) + -> means join concatenate. it is used to merge small small condition so we can make complete condition.
# 4) \. -> dot is escape sequence character or special character. so here backslash is used to drop special character.
# it is treated as dot not special charater if we used backslash.


# 5) ? means -> dot 0 ya 1 hi hona chahiye. 0 means kuch bhi ni to bhi shi hai. but more than 1 ni hone chahiye.
# other wise string will not match with our pattern.

    
# 6) [a-z 0-9] -> also [a-z]+[0-9] hm group of words and no. ko ek sath bhi de skte hai and alg alg bhi

# Enter your Email :  wscube@gmail.com
# Right Email 

# Enter your Email :  wscube.@gmail.com
# Wrong Email
# Out:
#  Enter your Email :  wscube@gmail.com
# Right Email

# %%
# completed

# %% [markdown]
# ## TO DO (also se regex by code with harry)
# # when free see this video also
